# %% [markdown]
# Question 1:
#
# Build a DNN with 20 hidden layers of 100 neurons each
# (that’s too many, but it’s the point of this exercise). Use
# He initialization and the swish activation function.

# %%
import tensorflow as tf
import keras

n_features = 32 * 32 * 3

inputs = keras.Input(shape=(n_features,))
x = inputs
for i in range(20):
    x = keras.layers.Dense(100, activation="swish", 
    kernel_initializer="he_normal")(x)


model = keras.Model(inputs, x)
model.summary()
# Out:
# Model: "functional_615"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_53 (InputLayer)     │ (None, 3072)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_957 (Dense)               │ (None, 100)            │       307,300 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_958 (Dense)               │ (None, 100)            │        10,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_959 (Dense)               │ (None, 100)            │        10,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_960 (Dense)               │ (None, 100)            │        10,100 │
# ...

# %% [markdown]
# Question 2:
#
# Using early stopping, train the network on the CIFAR10
# dataset. You can load it with
# tf.keras.datasets.cifar10.load_data() (I suggest consulting
# the appropriate documentation for how to load properly
# load this data into your environment). The dataset is
# composed of 60,000 32 × 32–pixel color images (50,000 for
# training, 10,000 for testing) with 10 classes, so you’ll
# need a softmax output layer with 10 neurons. Remember to
# search for the right learning rate each time you change the
# model’s architecture or hyperparameters.

# %%
import tensorflow as tf
import keras
import numpy as np
from tensorflow import keras

cifardata = tf.keras.datasets.cifar10.load_data()
n_features = 32*32*3 #data shape is 32x32 pixels with 3 color channels
model = keras.models.Sequential()
model.add(keras.layers.InputLayer(input_shape=(n_features,)))

for _ in range(20):
    model.add(keras.layers.Dense(100, activation="swish", kernel_initializer="he_normal"))
model.add(keras.layers.Dense(10, activation="softmax"))

model.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.Adam(learning_rate=0.01),
              metrics=["accuracy"])

(X_train_full, y_train_full), (X_test, y_test) = cifardata
X_train, y_train = X_train_full[:10000], y_train_full[:10000]
X_valid, y_valid = X_train_full[-10000:], y_train_full[-10000:]

pixel_means = X_train.mean(axis=0, keepdims=True)
pixel_stds = X_train.std(axis=0, keepdims=True)
X_train_scaled = (X_train - pixel_means) / pixel_stds
X_valid_scaled = (X_valid - pixel_means) / pixel_stds
X_test_scaled = (X_test - pixel_means) / pixel_stds

X_train_flat = X_train_scaled.reshape((X_train_scaled.shape[0], -1))
X_valid_flat = X_valid_scaled.reshape((X_valid_scaled.shape[0], -1))
X_test_flat = X_test_scaled.reshape((X_test_scaled.shape[0], -1))


early_stopping = keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

history = model.fit(X_train_flat, y_train, epochs=100, batch_size=512,
                    validation_data=(X_valid_flat, y_valid),
                    callbacks=[early_stopping])

test_loss, test_acc = model.evaluate(X_test_flat, y_test, verbose=0)
print(f"Test accuracy: {test_acc:.4f} | Test loss: {test_loss:.4f}")
# Out:
# Epoch 1/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.1215 - loss: 13.2807 - val_accuracy: 0.1630 - val_loss: 2.2551
# Epoch 2/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1692 - loss: 2.2346 - val_accuracy: 0.1926 - val_loss: 2.1893
# Epoch 3/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1988 - loss: 2.1367 - val_accuracy: 0.2181 - val_loss: 2.0968
# Epoch 4/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.2169 - loss: 2.0934 - val_accuracy: 0.2075 - val_loss: 2.1060
# Epoch 5/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.2286 - loss: 2.0584 - val_accuracy: 0.2366 - val_loss: 2.0353
# Epoch 6/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.2430 - loss: 2.0088 - val_accuracy: 0.2511 - val_loss: 1.9961
# Epoch 7/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.2565 - loss: 1.9713 - val_accuracy: 0.2532 - val_loss: 1.9995
# Epoch 8/100
# ...

# %% [markdown]
# Question 3:
#
# Now try adding Batch Normalization and compare the
# learning curves: Is it converging faster than before? Does
# it produce a better model? How does it affect training
# speed?
#
#
#
# Answer:
# So when switching to batch normalization and comparing to Q2 without batch I have an increased training ms/step amount. Meaning it's taking longer for my model to train. Accuracy differences are lower during the beginning epochs and then begins to outpace in the later epochs. Nothing to crazy but there is a slight bump in accuracy.
#
# Now these accuracies are pretty bad, so there must be something wrong with my model. I have fiddled with the learning rates, epochs, batch sizes, and the early stopping time but can't seem to get a higher learning rate nailed down. Would you please offer feedback on what I'm doing wrong? This comment is more general to my entire homework not so much as just for question 3. This is batch normalization on a fairly DNN.

# %%
import tensorflow as tf
import keras
import numpy as np
from tensorflow import keras

cifardata = tf.keras.datasets.cifar10.load_data()
n_features = 32*32*3
model = keras.models.Sequential([
    tf.keras.layers.BatchNormalization(input_shape=(n_features,)),
])
for _ in range(20):
    model.add(keras.layers.Dense(100, activation="swish", kernel_initializer="he_normal"))
model.add(keras.layers.Dense(10, activation="softmax"))

model.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.Adam(learning_rate=0.01),
              metrics=["accuracy"])

(X_train_full, y_train_full), (X_test, y_test) = cifardata
X_train, y_train = X_train_full[:10000], y_train_full[:10000]
X_valid, y_valid = X_train_full[-10000:], y_train_full[-10000:]

pixel_means = X_train.mean(axis=0, keepdims=True)
pixel_stds = X_train.std(axis=0, keepdims=True)
X_train_scaled = (X_train - pixel_means) / pixel_stds
X_valid_scaled = (X_valid - pixel_means) / pixel_stds
X_test_scaled = (X_test - pixel_means) / pixel_stds

X_train_flat = X_train_scaled.reshape((X_train_scaled.shape[0], -1))
X_valid_flat = X_valid_scaled.reshape((X_valid_scaled.shape[0], -1))
X_test_flat = X_test_scaled.reshape((X_test_scaled.shape[0], -1))


early_stopping = keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

history = model.fit(X_train_flat, y_train, epochs=100, batch_size=512,
                    validation_data=(X_valid_flat, y_valid),
                    callbacks=[early_stopping])

test_loss, test_acc = model.evaluate(X_test_flat, y_test, verbose=0)
print(f"Test accuracy: {test_acc:.4f} | Test loss: {test_loss:.4f}")
# Out:
# c:\Users\PC\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\normalization\batch_normalization.py:142: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - accuracy: 0.1194 - loss: 4.8482 - val_accuracy: 0.1421 - val_loss: 2.3084
# Epoch 2/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.1560 - loss: 2.2581 - val_accuracy: 0.1523 - val_loss: 2.2284
# Epoch 3/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.1776 - loss: 2.1868 - val_accuracy: 0.1705 - val_loss: 2.2063
# Epoch 4/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.1927 - loss: 2.1296 - val_accuracy: 0.1973 - val_loss: 2.0932
# Epoch 5/100
# ...

# %% [markdown]
# Question 4:
#
# Try replacing Batch Normalization with SELU, and make the
# necessary adjustments to ensure the network selfnormalizes
# (i.e., standardize the input features, use LeCun
# normal initialization, make sure the DNN contains only a
# sequence of dense layers). How does the performance
# change?
#
#
# Answer: Switching to SELU has significantly increase my performance. Now why is this? SELU is more attuned to be used on deep networks and I believe a 20 layer is fairly deep so SELU will have a higher effectiveness than a batch normalization stabilizer because it's more of a generalized tool (from my understanding).

# %%
import tensorflow as tf
import keras
import numpy as np
from tensorflow import keras

cifardata = tf.keras.datasets.cifar10.load_data()
model = keras.models.Sequential()
n_features = 32*32*3
model.add(keras.layers.InputLayer(shape=(n_features,)))

for _ in range(20):
    model.add(keras.layers.Dense(100, activation="selu", kernel_initializer="lecun_normal"))
model.add(keras.layers.Dense(10, activation="softmax"))

model.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.SGD(learning_rate=0.01),
              metrics=["accuracy"])

(X_train_full, y_train_full), (X_test, y_test) = cifardata
X_train, y_train = X_train_full[:10000], y_train_full[:10000]
X_valid, y_valid = X_train_full[-10000:], y_train_full[-10000:]

pixel_means = X_train.mean(axis=0, keepdims=True)
pixel_stds = X_train.std(axis=0, keepdims=True)
X_train_scaled = (X_train - pixel_means) / pixel_stds
X_valid_scaled = (X_valid - pixel_means) / pixel_stds
X_test_scaled = (X_test - pixel_means) / pixel_stds

X_train_flat = X_train_scaled.reshape((X_train_scaled.shape[0], -1))
X_valid_flat = X_valid_scaled.reshape((X_valid_scaled.shape[0], -1))
X_test_flat = X_test_scaled.reshape((X_test_scaled.shape[0], -1))


early_stopping = keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

history = model.fit(X_train_flat, y_train, epochs=100, batch_size=512,
                    validation_data=(X_valid_flat, y_valid),
                    callbacks=[early_stopping])

test_loss, test_acc = model.evaluate(X_test_flat, y_test, verbose=0)
print(f"Test accuracy: {test_acc:.4f} | Test loss: {test_loss:.4f}")
# Out:
# Epoch 1/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.2346 - loss: 2.1786 - val_accuracy: 0.2703 - val_loss: 2.0330
# Epoch 2/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.3092 - loss: 1.9264 - val_accuracy: 0.3045 - val_loss: 1.9630
# Epoch 3/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.3486 - loss: 1.8176 - val_accuracy: 0.3228 - val_loss: 1.9180
# Epoch 4/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.3686 - loss: 1.7629 - val_accuracy: 0.3336 - val_loss: 1.8927
# Epoch 5/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.3977 - loss: 1.6919 - val_accuracy: 0.3351 - val_loss: 1.8697
# Epoch 6/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.4163 - loss: 1.6363 - val_accuracy: 0.3506 - val_loss: 1.8453
# Epoch 7/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.4211 - loss: 1.6228 - val_accuracy: 0.3538 - val_loss: 1.8310
# Epoch 8/100
# ...
